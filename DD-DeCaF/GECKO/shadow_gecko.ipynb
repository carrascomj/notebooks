# %% [markdown]
# # Shadow prices on GECKOpy

# %%
from geckopy import GeckoModel
import pandas

# %%
model = GeckoModel('multi-pool')

some_measurements = pandas.Series({'P00549': 0.1, 'P31373': 0.1, 'P31382': 0.1})
model.limit_proteins(some_measurements)
solution = model.optimize()

# %%
solution
# Out:
# <Solution 0.090 at 0x7fe85931ecf8>

# %%
print(f"""Number of shadow prices -> {len(solution.shadow_prices)}
Number of fluxes in solution -> {len(solution.fluxes)}""")
# Out:
# Number of shadow prices -> 3493
# Number of fluxes in solution -> 6910

# %% [markdown]
# ### Clean way
# This first method would look for the variable corresponding to the protein in every constraint expression to do the mapping from enzyme to constraint.

# %%
pandas.DataFrame(solution.shadow_prices)
# Out:
#                      shadow_prices
# s_0001_ce                -0.067989
# s_0002_c                 -0.067989
# s_0003_e                 -0.059675
# s_0004_ce                -0.066314
# s_0006_m                  0.000000
# s_0007_c                  0.000000
# s_0008_m                 -0.087176
# s_0009_c                 -0.086254
# s_0010_c                 -0.082570
# s_0011_m                 -0.082570
# s_0012_m                 -0.075693
# s_0013_c                 -0.000000
# s_0014_n                 -0.000000
# s_0015_c                 -0.150316
# s_0016_m                 -0.057375
# s_0017_c                  0.064242
# s_0018_c                 -0.102464
# s_0019_c                 -0.097027
# s_0020_c                  0.004148
# s_0021_c                 -0.213377
# s_0022_e                 -0.213377
# s_0023_m                 -0.213377
# s_0024_p                 -0.212568
# s_0025_c                 -0.039967
# s_0026_e                 -0.033358
# s_0027_m                 -0.041146
# s_0028_c                 -0.086340
# s_0029_e                 -0.086340
# s_0030_c                  0.023522
# s_0031_c                 -0.006610
# ...                            ...
# pmet_r_0294_REV_lp        0.000000
# pmet_r_0295_REV_lp        0.000000
# pmet_r_0366_REV_c        -0.039136
# pmet_r_0483_REV_c        -0.032219
# pmet_r_0486_REV_c        -0.047087
# pmet_r_0523_REV_er        0.000000
# pmet_r_0542_REV_m        -0.089845
# pmet_r_0570_REV_c        -0.486040
# pmet_r_0815_REV_c        -0.154246
# pmet_r_0820_REV_c        -0.149253
# pmet_r_0888_REV_c        -0.070113
# pmet_r_0907_REV_c        -0.060367
# pmet_r_0912_REV_c        -0.483039
# pmet_r_1021_REV_m        -0.045919
# pmet_r_1031_REV_c        -0.563177
# pmet_r_1049_REV_c        -0.120684
# pmet_r_1050_REV_c        -0.110499
# pmet_r_1084_REV_c        -0.206450
# pmet_r_1095_REV_c        -0.135169
# pmet_r_2195_REV_erm      -0.251824
# pmet_r_2196_REV_erm      -0.586560
# pmet_r_2197_REV_erm      -0.604431
# pmet_r_2198_REV_erm      -0.618601
# pmet_r_2199_REV_erm      -0.653643
# pmet_r_2201_REV_lp       -0.473041
# pmet_r_2202_REV_lp       -0.586560
# pmet_r_2203_REV_lp       -0.604431
# pmet_r_2204_REV_lp       -0.648883
# pmet_r_2205_REV_lp       -0.653643
# prot_pool                -0.387511
#
# [3493 rows x 1 columns]

# %% [markdown]
# Notice how names and rows of shadow prices corresponds to those of constraints.

# %%
cons = pandas.DataFrame(model.constraints)
cons
# Out:
#                                                       0
# 0     s_0001_ce: 0.0 <= 1.0*r_0005No1 - 1.0*r_0005No...
# 1     s_0002_c: 0.0 <= 1.0*r_1543 - 1.0*r_1543_REV +...
# 2     s_0003_e: 0.0 <= -1.0*arm_r_0370 + 1.0*arm_r_0...
# 3     s_0004_ce: 0.0 <= 1.0*r_0006 - 1.0*r_0006_reve...
# 4     s_0006_m: 0.0 <= 1.0*r_0017No1 - 1.0*r_0017No1...
# 5     s_0007_c: 0.0 <= 1.0*r_1046No1 - 1.0*r_1046No1...
# 6     s_0008_m: 0.0 <= -1.0*r_0353No1 + 1.0*r_0353No...
# 7     s_0009_c: 0.0 <= -1.0*r_0059No1 + 1.0*r_0059No...
# 8     s_0010_c: 0.0 <= -1.0*r_0029No1 + 1.0*r_0029No...
# 9     s_0011_m: 0.0 <= -1.0*r_0030No1 + 1.0*r_0030No...
# 10    s_0012_m: 0.0 <= 1.0*r_0117No1 - 1.0*r_0117No1...
# 11    s_0013_c: 0.0 <= 1.0*r_0703No1 - 1.0*r_0703No1...
# 12    s_0014_n: 0.0 <= 1.0*r_0704No1 - 1.0*r_0704No1...
# 13    s_0015_c: 0.0 <= -1.0*r_0207No1 + 1.0*r_0207No...
# 14    s_0016_m: 0.0 <= 1.0*r_0096No1 - 1.0*r_0096No1...
# 15    s_0017_c: 0.0 <= 1.0*r_0842No1 - 1.0*r_0842No1...
# 16    s_0018_c: 0.0 <= -1.0*r_0739No1 + 1.0*r_0739No...
# 17    s_0019_c: 0.0 <= 1.0*r_0735No1 - 1.0*r_0735No1...
# 18    s_0020_c: 0.0 <= 1.0*r_0003No1 - 1.0*r_0003No1...
# 19    s_0021_c: 0.0 <= -1.0*arm_r_0252 + 1.0*arm_r_0...
# 20    s_0022_e: 0.0 <= -1.0*r_1191 + 1.0*r_1191_REV ...
# 21    s_0023_m: 0.0 <= 1.0*r_0254No1 - 1.0*r_0254No1...
# 22    s_0024_p: 0.0 <= -1.0*r_0253No1 + 1.0*r_0253No...
# 23    s_0025_c: 0.0 <= -1.0*arm_r_0001 + 1.0*arm_r_0...
# 24    s_0026_e: 0.0 <= -1.0*r_1136 + 1.0*r_1136_REV ...
# 25    s_0027_m: 0.0 <= -1.0*arm_r_0002 + 1.0*arm_r_0...
# 26    s_0028_c: 0.0 <= 1.0*r_0558No1 - 1.0*r_0558No1...
# 27    s_0029_e: 0.0 <= -1.0*r_1096 + 1.0*r_1096_REV ...
# 28    s_0030_c: 0.0 <= 1.0*r_0019No1 - 1.0*r_0019No1...
# 29    s_0031_c: 0.0 <= -1.0*r_0842No1 + 1.0*r_0842No...
# ...                                                 ...
# 3463  pmet_r_0294_REV_lp: 0.0 <= 1.0*arm_r_0294_REV ...
# 3464  pmet_r_0295_REV_lp: 0.0 <= 1.0*arm_r_0295_REV ...
# 3465  pmet_r_0366_REV_c: 0.0 <= 1.0*arm_r_0366_REV -...
# 3466  pmet_r_0483_REV_c: 0.0 <= 1.0*arm_r_0483_REV -...
# 3467  pmet_r_0486_REV_c: 0.0 <= 1.0*arm_r_0486_REV -...
# 3468  pmet_r_0523_REV_er: 0.0 <= 1.0*arm_r_0523_REV ...
# 3469  pmet_r_0542_REV_m: 0.0 <= 1.0*arm_r_0542_REV -...
# 3470  pmet_r_0570_REV_c: 0.0 <= 1.0*arm_r_0570_REV -...
# 3471  pmet_r_0815_REV_c: 0.0 <= 1.0*arm_r_0815_REV -...
# 3472  pmet_r_0820_REV_c: 0.0 <= 1.0*arm_r_0820_REV -...
# 3473  pmet_r_0888_REV_c: 0.0 <= 1.0*arm_r_0888_REV -...
# 3474  pmet_r_0907_REV_c: 0.0 <= 1.0*arm_r_0907_REV -...
# 3475  pmet_r_0912_REV_c: 0.0 <= 1.0*arm_r_0912_REV -...
# 3476  pmet_r_1021_REV_m: 0.0 <= 1.0*arm_r_1021_REV -...
# 3477  pmet_r_1031_REV_c: 0.0 <= 1.0*arm_r_1031_REV -...
# 3478  pmet_r_1049_REV_c: 0.0 <= 1.0*arm_r_1049_REV -...
# 3479  pmet_r_1050_REV_c: 0.0 <= 1.0*arm_r_1050_REV -...
# 3480  pmet_r_1084_REV_c: 0.0 <= 1.0*arm_r_1084_REV -...
# 3481  pmet_r_1095_REV_c: 0.0 <= 1.0*arm_r_1095_REV -...
# 3482  pmet_r_2195_REV_erm: 0.0 <= 1.0*arm_r_2195_REV...
# 3483  pmet_r_2196_REV_erm: 0.0 <= 1.0*arm_r_2196_REV...
# 3484  pmet_r_2197_REV_erm: 0.0 <= 1.0*arm_r_2197_REV...
# 3485  pmet_r_2198_REV_erm: 0.0 <= 1.0*arm_r_2198_REV...
# 3486  pmet_r_2199_REV_erm: 0.0 <= 1.0*arm_r_2199_REV...
# 3487  pmet_r_2201_REV_lp: 0.0 <= 1.0*arm_r_2201_REV ...
# 3488  pmet_r_2202_REV_lp: 0.0 <= 1.0*arm_r_2202_REV ...
# 3489  pmet_r_2203_REV_lp: 0.0 <= 1.0*arm_r_2203_REV ...
# 3490  pmet_r_2204_REV_lp: 0.0 <= 1.0*arm_r_2204_REV ...
# 3491  pmet_r_2205_REV_lp: 0.0 <= 1.0*arm_r_2205_REV ...
# 3492  prot_pool: 0 <= -29.272*draw_prot_A2P2R3 + 29....
#
# [3493 rows x 1 columns]

# %%
print(model.reactions.r_4048.flux_expression)
con = cons.iloc[3,0]
con.expression
# Out:
# 1.0*r_4048 - 1.0*r_4048_reverse_e212d
# 1.0*r_0006 - 1.0*r_0006_reverse_ff4c7 - 0.239185*r_4048 + 0.239185*r_4048_reverse_e212d

# %%
model.reactions.r_0006.forward_variable in [fun.args[1] for fun in con.expression.args]
# Out:
# True

# %% [markdown]
# Doing that last operation iteratively, we could get the complete mapping.

# %% [markdown]
# ### Quick and dirty: regex
#
# Notice here that the "prot_" constraints are related to proteins.

# %%
shadow_ps = pandas.DataFrame(solution.shadow_prices)
shadow_ps
# Out:
#                      shadow_prices
# s_0001_ce                -0.067989
# s_0002_c                 -0.067989
# s_0003_e                 -0.059675
# s_0004_ce                -0.066314
# s_0006_m                  0.000000
# s_0007_c                  0.000000
# s_0008_m                 -0.087176
# s_0009_c                 -0.086254
# s_0010_c                 -0.082570
# s_0011_m                 -0.082570
# s_0012_m                 -0.075693
# s_0013_c                 -0.000000
# s_0014_n                 -0.000000
# s_0015_c                 -0.150316
# s_0016_m                 -0.057375
# s_0017_c                  0.064242
# s_0018_c                 -0.102464
# s_0019_c                 -0.097027
# s_0020_c                  0.004148
# s_0021_c                 -0.213377
# s_0022_e                 -0.213377
# s_0023_m                 -0.213377
# s_0024_p                 -0.212568
# s_0025_c                 -0.039967
# s_0026_e                 -0.033358
# s_0027_m                 -0.041146
# s_0028_c                 -0.086340
# s_0029_e                 -0.086340
# s_0030_c                  0.023522
# s_0031_c                 -0.006610
# ...                            ...
# pmet_r_0294_REV_lp        0.000000
# pmet_r_0295_REV_lp        0.000000
# pmet_r_0366_REV_c        -0.039136
# pmet_r_0483_REV_c        -0.032219
# pmet_r_0486_REV_c        -0.047087
# pmet_r_0523_REV_er        0.000000
# pmet_r_0542_REV_m        -0.089845
# pmet_r_0570_REV_c        -0.486040
# pmet_r_0815_REV_c        -0.154246
# pmet_r_0820_REV_c        -0.149253
# pmet_r_0888_REV_c        -0.070113
# pmet_r_0907_REV_c        -0.060367
# pmet_r_0912_REV_c        -0.483039
# pmet_r_1021_REV_m        -0.045919
# pmet_r_1031_REV_c        -0.563177
# pmet_r_1049_REV_c        -0.120684
# pmet_r_1050_REV_c        -0.110499
# pmet_r_1084_REV_c        -0.206450
# pmet_r_1095_REV_c        -0.135169
# pmet_r_2195_REV_erm      -0.251824
# pmet_r_2196_REV_erm      -0.586560
# pmet_r_2197_REV_erm      -0.604431
# pmet_r_2198_REV_erm      -0.618601
# pmet_r_2199_REV_erm      -0.653643
# pmet_r_2201_REV_lp       -0.473041
# pmet_r_2202_REV_lp       -0.586560
# pmet_r_2203_REV_lp       -0.604431
# pmet_r_2204_REV_lp       -0.648883
# pmet_r_2205_REV_lp       -0.653643
# prot_pool                -0.387511
#
# [3493 rows x 1 columns]

# %%
top10_prot = solution.shadow_prices.filter(regex='^prot').sort_values()[:10]
solution.shadow_prices.filter(regex='^prot').sort_values()[:10]
# Out:
# prot_P34756_c   -99.752958
# prot_Q00955_c   -97.014421
# prot_P07259_c   -94.955965
# prot_Q12680_c   -92.267030
# prot_P07149_c   -88.620168
# prot_P37297_c   -83.162470
# prot_Q04952_c   -80.401845
# prot_P40989_c   -80.401845
# prot_P19097_c   -80.194139
# prot_P32528_c   -78.212023
# Name: shadow_prices, dtype: float64

# %% [markdown]
# To display it, we can just show the ids. Maybe it would be important to sort by absolute value.

# %%
import re

prot_id_pat = re.compile(r"^prot_(.+)_.+")
show = {re.sub(prot_id_pat, r"\1", prot_id): val for prot_id, val in zip(top10_prot.index, top10_prot)}
pandas.DataFrame.from_dict(show, orient='index')
# Out:
#                 0
# P34756 -99.752958
# Q00955 -97.014421
# P07259 -94.955965
# Q12680 -92.267030
# P07149 -88.620168
# P37297 -83.162470
# Q04952 -80.401845
# P40989 -80.401845
# P19097 -80.194139
# P32528 -78.212023

# %%
model.metabolites.prot_P32874_c.reactions
# Out:
# frozenset({<Reaction draw_prot_P32874 at 0x7fe85033ca58>,
#            <Reaction r_0108No1 at 0x7fe858ecb470>})
