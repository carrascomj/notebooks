# %% [markdown]
# # Inspect the profile of new test function
# We are interested in speeding up the test of metabolite production. However, even with the new logic, it is still too slow.

# %%
import pandas as pd
import cobra
import numpy as np

import cProfile
import pstats

# %% [markdown]
# Functions to test.

# %%
def open_exchanges(model):
    for rxn in model.exchanges:
        rxn.bounds = (-1000, 1000)

def solve_boundary(metabolite, rxn, val=-1):
    """
    Solves the model when some reaction `rxn` has been added to the `metabolite`'s contraints.
    """
    constraint = metabolite.constraint
    constraint.set_linear_coefficients({rxn: val})
    solution = metabolite.model.slim_optimize()
    # TODO: it seems like with context doesn't catch these changes, need to check
    # restore constraint
    constraint.set_linear_coefficients({rxn: 0})
    return solution

def run_fba(model, rxn_id, direction="max", single_value=True):
    model.objective = model.reactions.get_by_id(rxn_id)
    model.objective_direction = direction
    if single_value:
        return model.slim_optimize()
    else:
        try:
            solution = model.optimize()
        except Infeasible:
            return solution
            return np.nan

def test_new(model):
    """
    New test
    """
    mets_not_produced = list()
    open_exchanges(model)
    irr = model.problem.Variable("irr", lb=0, ub=1000)
    with model:
        model.add_cons_vars(irr)
        # helper.run_fba() only accepts reactions in the model
        model.objective = irr
        for met in model.metabolites:
            solution = solve_boundary(met, irr)
            if np.isnan(solution) or solution < model.tolerance:
                mets_not_produced.append(met)
    return mets_not_produced

def test_old(model):
    """
    old_test in consistency.py
    """
    mets_not_produced = list()
    open_exchanges(model)
    for met in model.metabolites:
        with model:
            exch = model.add_boundary(
                met, type="irrex", reaction_id="IRREX", lb=0, ub=1000
            )
            solution = run_fba(model, exch.id)
            if np.isnan(solution) or solution < model.tolerance:
                mets_not_produced.append(met)
    return mets_not_produced

# %% [markdown]
# ## Profiling of new test
# First, write them to file and then use the pstats library to parse the output (which has a REALLY annoying format).

# %%
model = cobra.io.read_sbml_model("iAB_RBC_283.xml")
model.solver = "glpk"


cProfile.run('test_new(model)', 'testats')
# Out:
# Academic license - for non-commercial use only

# %% [markdown]
# Now, read from file with pstats from the standard library.

# %%
p_new = pstats.Stats('testats')
p_new.strip_dirs().sort_stats(2).print_stats()
# Out:
# Thu Nov  7 10:46:05 2019    testats
#
#          201481 function calls (199744 primitive calls) in 2.069 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    2.069    2.069 {built-in method builtins.exec}
#         1    0.000    0.000    2.069    2.069 <string>:1(<module>)
#         1    0.004    0.004    2.069    2.069 <ipython-input-2-2558f62ab766>:29(test_new)
#       342    0.004    0.000    2.045    0.006 <ipython-input-2-2558f62ab766>:5(solve_boundary)
#       342    0.002    0.000    1.911    0.006 model.py:1020(slim_optimize)
#       342    0.001    0.000    1.905    0.006 interface.py:1454(optimize)
#       342    0.001    0.000    1.903    0.006 glpk_interface.py:700(_optimize)
#       478    0.002    0.000    1.845    0.004 glpk_interface.py:674(_run_glp_simplex)
#       478    1.842    0.004    1.842    0.004 {built-in method swiglpk._swiglpk.glp_simplex}
#       684    0.031    0.000    0.125    0.000 glpk_interface.py:262(set_linear_coefficients)
#       136    0.055    0.000    0.055    0.000 {built-in method swiglpk._swiglpk.glp_adv_basis}
#       684    0.008    0.000    0.020    0.000 glpk_interface.py:275(<dictcomp>)
#         1    0.000    0.000    0.019    0.019 <ipython-input-2-2558f62ab766>:1(open_exchanges)
#      7535    0.008    0.000    0.016    0.000 glpk_interface.py:90(_index)
#         1    0.000    0.000    0.015    0.015 model.py:956(exchanges)
#         1    0.000    0.000    0.015    0.015 boundary_types.py:132(find_boundary_types)
#      1368    0.005    0.000    0.014    0.000 swiglpk.py:1695(__init__)
#         1    0.000    0.000    0.011    0.011 boundary_types.py:26(find_external_compartment)
#      7867    0.010    0.000    0.010    0.000 container.py:80(__getitem__)
#      1368    0.003    0.000    0.009    0.000 swiglpk.py:1730(__init__)
#      7535    0.006    0.000    0.006    0.000 {built-in method swiglpk._swiglpk.glp_find_col}
#      7372    0.003    0.000    0.006    0.000 swiglpk.py:1707(__setitem__)
#      1529    0.004    0.000    0.006    0.000 interface.py:1417(update)
#      7372    0.002    0.000    0.005    0.000 swiglpk.py:1742(__setitem__)
#      2736    0.004    0.000    0.005    0.000 swiglpk.py:77(_swig_getattr)
#      7030    0.002    0.000    0.005    0.000 swiglpk.py:1739(__getitem__)
#      1368    0.002    0.000    0.005    0.000 glpk_interface.py:219(_index)
#      7030    0.002    0.000    0.005    0.000 swiglpk.py:1704(__getitem__)
#       342    0.001    0.000    0.004    0.000 glpk_interface.py:334(value)
#       342    0.001    0.000    0.004    0.000 metabolite.py:62(constraint)
#      1368    0.001    0.000    0.004    0.000 swiglpk.py:1692(<lambda>)
#        76    0.000    0.000    0.004    0.000 context.py:60(wrapper)
#      2736    0.001    0.000    0.004    0.000 swiglpk.py:73(_swig_setattr)
#        76    0.000    0.000    0.004    0.000 reaction.py:296(bounds)
#       684    0.001    0.000    0.004    0.000 glpk_interface.py:804(_glpk_is_mip)
#         1    0.000    0.000    0.004    0.004 base.py:1304(value_counts)
#         1    0.000    0.000    0.004    0.004 algorithms.py:695(value_counts)
#        76    0.000    0.000    0.004    0.000 reaction.py:197(update_variable_bounds)
#         6    0.000    0.000    0.004    0.001 series.py:194(__init__)
#        59    0.000    0.000    0.004    0.000 abc.py:180(__instancecheck__)
#      1776    0.001    0.000    0.004    0.000 reaction.py:542(boundary)
#    316/14    0.001    0.000    0.003    0.000 abc.py:196(__subclasscheck__)
#         3    0.000    0.000    0.003    0.001 model.py:949(boundary)
#         3    0.000    0.000    0.003    0.001 model.py:954(<listcomp>)
#         1    0.000    0.000    0.003    0.003 dictlist.py:94(query)
#         1    0.000    0.000    0.003    0.003 dictlist.py:201(_extend_nocheck)
#       684    0.003    0.000    0.003    0.000 {built-in method swiglpk._swiglpk.glp_get_num_int}
#      7372    0.003    0.000    0.003    0.000 {built-in method swiglpk._swiglpk.intArray___setitem__}
#   897/276    0.000    0.000    0.003    0.000 {built-in method builtins.issubclass}
#      1368    0.001    0.000    0.003    0.000 swiglpk.py:1690(<lambda>)
#        77    0.000    0.000    0.003    0.000 dictlist.py:147(<genexpr>)
#       469    0.000    0.000    0.003    0.000 boundary_types.py:160(<lambda>)
#      7372    0.003    0.000    0.003    0.000 {built-in method swiglpk._swiglpk.doubleArray___setitem__}
#         1    0.000    0.000    0.003    0.003 series.py:3023(sort_values)
#       469    0.001    0.000    0.003    0.000 boundary_types.py:85(is_boundary_type)
#      1368    0.001    0.000    0.003    0.000 swiglpk.py:1727(<lambda>)
#      1962    0.002    0.000    0.003    0.000 six.py:586(iteritems)
#      2736    0.003    0.000    0.003    0.000 swiglpk.py:54(_swig_setattr_nondynamic)
#      7030    0.002    0.000    0.002    0.000 {built-in method swiglpk._swiglpk.glp_get_col_name}
# 1821/1601    0.001    0.000    0.002    0.000 {built-in method builtins.isinstance}
#      7030    0.002    0.000    0.002    0.000 {built-in method swiglpk._swiglpk.doubleArray___getitem__}
#      7030    0.002    0.000    0.002    0.000 {built-in method swiglpk._swiglpk.intArray___getitem__}
#    298/85    0.000    0.000    0.002    0.000 typing.py:1145(__subclasscheck__)
#       342    0.000    0.000    0.002    0.000 model.py:933(constraints)
#      1368    0.001    0.000    0.002    0.000 swiglpk.py:1725(<lambda>)
#     11476    0.002    0.000    0.002    0.000 glpk_interface.py:206(problem)
#         2    0.000    0.000    0.002    0.001 common.py:297(maybe_iterable_to_list)
#      1368    0.002    0.000    0.002    0.000 {built-in method swiglpk._swiglpk.glp_find_row}
#       684    0.002    0.000    0.002    0.000 {built-in method swiglpk._swiglpk.glp_set_mat_row}
#        16    0.000    0.000    0.002    0.000 {pandas._libs.lib.is_list_like}
#       342    0.000    0.000    0.002    0.000 interface.py:1206(constraints)
# 13106/13082    0.002    0.000    0.002    0.000 {built-in method builtins.len}
#       152    0.000    0.000    0.002    0.000 glpk_interface.py:114(set_bounds)
# 3443/3100    0.001    0.000    0.001    0.000 {built-in method builtins.getattr}
#      8228    0.001    0.000    0.001    0.000 interface.py:182(name)
#      1368    0.001    0.000    0.001    0.000 {built-in method swiglpk._swiglpk.new_intArray}
#      1776    0.001    0.000    0.001    0.000 reaction.py:414(metabolites)
#       153    0.001    0.000    0.001    0.000 glpk_interface.py:777(_glpk_set_col_bounds)
#       684    0.001    0.000    0.001    0.000 {built-in method swiglpk._swiglpk.glp_get_mat_row}
#        76    0.000    0.000    0.001    0.000 reaction.py:147(reverse_variable)
#         7    0.000    0.000    0.001    0.000 base.py:4262(__getitem__)
#      1381    0.001    0.000    0.001    0.000 interface.py:439(problem)
#       684    0.001    0.000    0.001    0.000 glpk_interface.py:273(<dictcomp>)
#     30/29    0.000    0.000    0.001    0.000 typing.py:875(__extrahook__)
#      1368    0.001    0.000    0.001    0.000 {built-in method swiglpk._swiglpk.new_doubleArray}
#       6/5    0.000    0.000    0.001    0.000 base.py:277(__new__)
#         6    0.000    0.000    0.001    0.000 construction.py:630(sanitize_array)
#       152    0.000    0.000    0.001    0.000 model.py:917(variables)
#       283    0.000    0.000    0.001    0.000 _weakrefset.py:58(__iter__)
#      3895    0.001    0.000    0.001    0.000 {method 'get' of 'dict' objects}
#       468    0.000    0.000    0.001    0.000 reaction.py:964(compartments)
#        76    0.000    0.000    0.001    0.000 reaction.py:132(forward_variable)
#       154    0.000    0.000    0.001    0.000 interface.py:1200(variables)
#         1    0.000    0.000    0.001    0.001 algorithms.py:772(_value_counts_arraylike)
#      1962    0.001    0.000    0.001    0.000 {built-in method builtins.iter}
#      1776    0.001    0.000    0.001    0.000 {method 'copy' of 'dict' objects}
#       136    0.000    0.000    0.001    0.000 __init__.py:1286(debug)
#       297    0.000    0.000    0.001    0.000 reaction.py:726(reactants)
#         1    0.000    0.000    0.001    0.001 model.py:1140(objective)
#       691    0.001    0.000    0.001    0.000 {method 'update' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 __init__.py:1126(wrapper)
#       646    0.000    0.000    0.000    0.000 object.py:25(id)
#         2    0.000    0.000    0.000    0.000 range.py:662(__getitem__)
#       297    0.000    0.000    0.000    0.000 reaction.py:731(products)
#        76    0.000    0.000    0.000    0.000 reaction.py:109(reverse_id)
#       478    0.000    0.000    0.000    0.000 {built-in method swiglpk._swiglpk.glp_get_status}
#         3    0.000    0.000    0.000    0.000 numeric.py:82(_shallow_copy)
#         2    0.000    0.000    0.000    0.000 series.py:4051(_reduce)
#        82    0.000    0.000    0.000    0.000 base.py:231(is_dtype)
#         3    0.000    0.000    0.000    0.000 base.py:652(_shallow_copy_with_infer)
#       685    0.000    0.000    0.000    0.000 {built-in method swiglpk._swiglpk.glp_get_num_cols}
#       468    0.000    0.000    0.000    0.000 reaction.py:968(<setcomp>)
#         6    0.000    0.000    0.000    0.000 managers.py:1470(__init__)
#        26    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_scalar}
#       137    0.000    0.000    0.000    0.000 __init__.py:1544(isEnabledFor)
#        79    0.000    0.000    0.000    0.000 common.py:1886(_is_dtype_type)
#         6    0.000    0.000    0.000    0.000 blocks.py:3241(make_block)
#         2    0.000    0.000    0.000    0.000 range.py:410(_shallow_copy)
#         5    0.000    0.000    0.000    0.000 base.py:5707(ensure_index)
#         1    0.000    0.000    0.000    0.000 solver.py:99(set_objective)
#      1532    0.000    0.000    0.000    0.000 model.py:124(solver)
#      1369    0.000    0.000    0.000    0.000 interface.py:429(name)
#         4    0.000    0.000    0.000    0.000 construction.py:759(_try_cast)
#       376    0.000    0.000    0.000    0.000 generic.py:7(_check)
#         2    0.000    0.000    0.000    0.000 model.py:211(compartments)
#      1978    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 model.py:213(<dictcomp>)
#       733    0.000    0.000    0.000    0.000 _weakrefset.py:70(__contains__)
#     19/13    0.000    0.000    0.000    0.000 _asarray.py:16(asarray)
#     27/21    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#         3    0.000    0.000    0.000    0.000 missing.py:48(isna)
#         1    0.000    0.000    0.000    0.000 base.py:1243(to_series)
#         3    0.000    0.000    0.000    0.000 missing.py:128(_isna_new)
#         6    0.000    0.000    0.000    0.000 blocks.py:3195(get_block_type)
#      1026    0.000    0.000    0.000    0.000 species.py:51(model)
#         2    0.000    0.000    0.000    0.000 glpk_interface.py:615(objective)
#      1368    0.000    0.000    0.000    0.000 swiglpk.py:1702(<lambda>)
#      1368    0.000    0.000    0.000    0.000 swiglpk.py:1737(<lambda>)
#       152    0.000    0.000    0.000    0.000 interface.py:229(set_bounds)
#       171    0.000    0.000    0.000    0.000 _weakrefset.py:26(__exit__)
#       393    0.000    0.000    0.000    0.000 boundary_types.py:112(<listcomp>)
#        59    0.000    0.000    0.000    0.000 common.py:1743(is_extension_array_dtype)
#         1    0.000    0.000    0.000    0.000 generic.py:11546(stat_func)
#         3    0.000    0.000    0.000    0.000 glpk_interface.py:310(__init__)
#         1    0.000    0.000    0.000    0.000 generic.py:11594(stat_func)
#         6    0.000    0.000    0.000    0.000 cast.py:986(maybe_cast_to_datetime)
#        61    0.000    0.000    0.000    0.000 dtypes.py:83(find)
#         5    0.000    0.000    0.000    0.000 common.py:1466(needs_i8_conversion)
#       137    0.000    0.000    0.000    0.000 __init__.py:1530(getEffectiveLevel)
#         3    0.000    0.000    0.000    0.000 series.py:886(__array__)
#         1    0.000    0.000    0.000    0.000 algorithms.py:61(_ensure_data)
#        32    0.000    0.000    0.000    0.000 common.py:539(is_datetime64tz_dtype)
#         1    0.000    0.000    0.000    0.000 model.py:1240(__exit__)
#        36    0.000    0.000    0.000    0.000 common.py:2020(pandas_dtype)
#       177    0.000    0.000    0.000    0.000 _weakrefset.py:81(add)
#         3    0.000    0.000    0.000    0.000 interface.py:869(__init__)
#         1    0.000    0.000    0.000    0.000 context.py:32(reset)
#       100    0.000    0.000    0.000    0.000 boundary_types.py:43(<genexpr>)
#         1    0.000    0.000    0.000    0.000 nanops.py:62(_f)
#         3    0.000    0.000    0.000    0.000 interface.py:411(__init__)
#       342    0.000    0.000    0.000    0.000 {built-in method swiglpk._swiglpk.glp_get_obj_val}
#         1    0.000    0.000    0.000    0.000 interface.py:856(clone)
#         1    0.000    0.000    0.000    0.000 solver.py:161(reset)
#         4    0.000    0.000    0.000    0.000 base.py:831(array)
#       171    0.000    0.000    0.000    0.000 _weakrefset.py:20(__enter__)
#         7    0.000    0.000    0.000    0.000 common.py:1284(is_datetime_or_timedelta_dtype)
#        78    0.000    0.000    0.000    0.000 context.py:39(get_context)
#         1    0.000    0.000    0.000    0.000 nanops.py:96(f)
#       342    0.000    0.000    0.000    0.000 model.py:167(tolerance)
#        14    0.000    0.000    0.000    0.000 common.py:1619(is_bool_dtype)
#         4    0.000    0.000    0.000    0.000 cast.py:880(maybe_infer_to_datetimelike)
#         1    0.000    0.000    0.000    0.000 nanops.py:829(reduction)
#        19    0.000    0.000    0.000    0.000 common.py:608(is_period_dtype)
#         2    0.000    0.000    0.000    0.000 cast.py:63(maybe_convert_platform)
#        24    0.000    0.000    0.000    0.000 common.py:678(is_categorical_dtype)
#         1    0.000    0.000    0.000    0.000 interface.py:390(_substitute_variables)
#         5    0.000    0.000    0.000    0.000 {pandas._libs.lib.infer_dtype}
#         1    0.000    0.000    0.000    0.000 nanops.py:469(nansum)
#        13    0.000    0.000    0.000    0.000 _dtype.py:319(_name_get)
#         6    0.000    0.000    0.000    0.000 common.py:99(is_bool_indexer)
#         2    0.000    0.000    0.000    0.000 missing.py:219(_isna_ndarraylike)
#        19    0.000    0.000    0.000    0.000 dtypes.py:912(is_dtype)
#         7    0.000    0.000    0.000    0.000 common.py:1163(is_datetime64_any_dtype)
#        14    0.000    0.000    0.000    0.000 common.py:508(is_datetime64_dtype)
#         1    0.000    0.000    0.000    0.000 __init__.py:1081(na_op)
#       765    0.000    0.000    0.000    0.000 interface.py:197(lb)
#        18    0.000    0.000    0.000    0.000 common.py:642(is_interval_dtype)
#         2    0.000    0.000    0.000    0.000 nanops.py:239(_get_values)
#       123    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#       347    0.000    0.000    0.000    0.000 glpk_interface.py:611(objective)
#        13    0.000    0.000    0.000    0.000 dtypes.py:1092(is_dtype)
#        10    0.000    0.000    0.000    0.000 base.py:569(_simple_new)
#         2    0.000    0.000    0.000    0.000 uuid.py:580(uuid1)
#        10    0.000    0.000    0.000    0.000 common.py:357(is_categorical)
#       342    0.000    0.000    0.000    0.000 interface.py:1212(status)
#         6    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#       297    0.000    0.000    0.000    0.000 reaction.py:729(<listcomp>)
#       125    0.000    0.000    0.000    0.000 typing.py:1019(_abc_negative_cache)
#        19    0.000    0.000    0.000    0.000 common.py:225(is_object_dtype)
#         3    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#         4    0.000    0.000    0.000    0.000 base.py:634(_shallow_copy)
#        47    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:997(_handle_fromlist)
#         4    0.000    0.000    0.000    0.000 common.py:1684(is_extension_type)
#        10    0.000    0.000    0.000    0.000 _ufunc_config.py:39(seterr)
#         4    0.000    0.000    0.000    0.000 numpy_.py:122(__init__)
#       153    0.000    0.000    0.000    0.000 {built-in method swiglpk._swiglpk.glp_set_col_bnds}
#       612    0.000    0.000    0.000    0.000 interface.py:213(ub)
#        13    0.000    0.000    0.000    0.000 numerictypes.py:365(issubdtype)
#         2    0.000    0.000    0.000    0.000 interface.py:1188(objective)
#        14    0.000    0.000    0.000    0.000 common.py:577(is_timedelta64_dtype)
#       469    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         6    0.000    0.000    0.000    0.000 series.py:416(_set_axis)
#         2    0.000    0.000    0.000    0.000 {pandas._libs.lib.maybe_convert_objects}
#         2    0.000    0.000    0.000    0.000 base.py:5801(default_index)
#       348    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#       201    0.000    0.000    0.000    0.000 {method '__subclasses__' of 'type' objects}
#       469    0.000    0.000    0.000    0.000 dictlist.py:124(select_attribute)
#         1    0.000    0.000    0.000    0.000 dictlist.py:52(_generate_index)
#        29    0.000    0.000    0.000    0.000 series.py:467(dtype)
#         2    0.000    0.000    0.000    0.000 nanops.py:1187(_maybe_null_out)
#       297    0.000    0.000    0.000    0.000 reaction.py:734(<listcomp>)
#         1    0.000    0.000    0.000    0.000 dictlist.py:54(<dictcomp>)
#        79    0.000    0.000    0.000    0.000 typing.py:1033(_abc_negative_cache_version)
#         6    0.000    0.000    0.000    0.000 blocks.py:120(__init__)
#       171    0.000    0.000    0.000    0.000 _weakrefset.py:52(_commit_removals)
#       380    0.000    0.000    0.000    0.000 reaction.py:551(model)
#         6    0.000    0.000    0.000    0.000 {method 'atoms' of 'symengine.lib.symengine_wrapper.Basic' objects}
#         6    0.000    0.000    0.000    0.000 generic.py:5181(__setattr__)
#         4    0.000    0.000    0.000    0.000 cast.py:866(maybe_castable)
#       117    0.000    0.000    0.000    0.000 typing.py:1089(__eq__)
#         4    0.000    0.000    0.000    0.000 numpy_.py:39(__init__)
#         3    0.000    0.000    0.000    0.000 cast.py:1239(construct_1d_object_array_from_listlike)
#       171    0.000    0.000    0.000    0.000 _weakrefset.py:16(__init__)
#         3    0.000    0.000    0.000    0.000 numeric.py:47(__new__)
#        76    0.000    0.000    0.000    0.000 {method 'hexdigest' of '_hashlib.HASH' objects}
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(prod)
#         5    0.000    0.000    0.000    0.000 _ufunc_config.py:441(__enter__)
#        76    0.000    0.000    0.000    0.000 {built-in method _hashlib.openssl_md5}
#         1    0.000    0.000    0.000    0.000 generic.py:227(_validate_dtype)
#         2    0.000    0.000    0.000    0.000 {method 'sum' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 __init__.py:47(create_string_buffer)
#         3    0.000    0.000    0.000    0.000 common.py:240(asarray_tuplesafe)
#         2    0.000    0.000    0.000    0.000 expression_parsing.py:21(parse_optimization_expression)
#        11    0.000    0.000    0.000    0.000 common.py:255(is_sparse)
#         3    0.000    0.000    0.000    0.000 interface.py:456(variables)
#         1    0.000    0.000    0.000    0.000 {method 'subs' of 'symengine.lib.symengine_wrapper.Basic' objects}
#         2    0.000    0.000    0.000    0.000 range.py:83(__new__)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:2792(prod)
#         1    0.000    0.000    0.000    0.000 glpk_interface.py:724(_add_variables)
#       136    0.000    0.000    0.000    0.000 glpk_interface.py:455(presolve)
#        29    0.000    0.000    0.000    0.000 managers.py:1558(dtype)
#        26    0.000    0.000    0.000    0.000 numerictypes.py:293(issubclass_)
#         2    0.000    0.000    0.000    0.000 _methods.py:36(_sum)
#        19    0.000    0.000    0.000    0.000 base.py:180(construct_from_string)
#         1    0.000    0.000    0.000    0.000 common.py:1407(is_datetimelike_v_numeric)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:73(_wrapreduction)
#         1    0.000    0.000    0.000    0.000 cast.py:1306(maybe_cast_to_integer_array)
#         5    0.000    0.000    0.000    0.000 {built-in method numpy.empty}
#       219    0.000    0.000    0.000    0.000 {built-in method sys._getframe}
#        30    0.000    0.000    0.000    0.000 common.py:1850(_get_dtype)
#         5    0.000    0.000    0.000    0.000 _ufunc_config.py:446(__exit__)
#       332    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         6    0.000    0.000    0.000    0.000 arrays.py:7(extract_array)
#         4    0.000    0.000    0.000    0.000 base.py:1884(is_all_dates)
#         1    0.000    0.000    0.000    0.000 algorithms.py:167(_reconstruct_data)
#         7    0.000    0.000    0.000    0.000 common.py:1006(is_signed_integer_dtype)
#         1    0.000    0.000    0.000    0.000 interface.py:893(_canonicalize)
#         1    0.000    0.000    0.000    0.000 glpk_interface.py:86(__init__)
#        60    0.000    0.000    0.000    0.000 common.py:211(<lambda>)
#         1    0.000    0.000    0.000    0.000 {built-in method pandas._libs.hashtable.value_count_object}
#         2    0.000    0.000    0.000    0.000 expression_parsing.py:67(_parse_linear_expression)
#         2    0.000    0.000    0.000    0.000 blocks.py:2771(__init__)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(array_equal)
#        97    0.000    0.000    0.000    0.000 _collections_abc.py:392(__subclasshook__)
#        76    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#       152    0.000    0.000    0.000    0.000 {built-in method math.isinf}
#         1    0.000    0.000    0.000    0.000 interface.py:160(__init__)
#         8    0.000    0.000    0.000    0.000 common.py:951(is_integer_dtype)
#        19    0.000    0.000    0.000    0.000 _collections_abc.py:72(_check_methods)
#        11    0.000    0.000    0.000    0.000 interface.py:451(expression)
#         9    0.000    0.000    0.000    0.000 series.py:453(name)
#         2    0.000    0.000    0.000    0.000 nanops.py:345(_wrap_results)
#         1    0.000    0.000    0.000    0.000 numeric.py:2299(array_equal)
#         2    0.000    0.000    0.000    0.000 nanops.py:196(_maybe_get_mask)
#       152    0.000    0.000    0.000    0.000 interface.py:1482(_set_variable_bounds_on_problem)
#         1    0.000    0.000    0.000    0.000 algorithms.py:199(_ensure_arraylike)
#        10    0.000    0.000    0.000    0.000 _ufunc_config.py:139(geterr)
#         8    0.000    0.000    0.000    0.000 series.py:559(_values)
#        12    0.000    0.000    0.000    0.000 generic.py:5162(__getattr__)
#         7    0.000    0.000    0.000    0.000 _collections_abc.py:252(__subclasshook__)
#         1    0.000    0.000    0.000    0.000 inference.py:246(is_array_like)
#         6    0.000    0.000    0.000    0.000 common.py:1585(is_float_dtype)
#         7    0.000    0.000    0.000    0.000 common.py:1825(_is_dtype)
#       171    0.000    0.000    0.000    0.000 {method 'remove' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 interface.py:471(is_Linear)
#        76    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#        26    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#         6    0.000    0.000    0.000    0.000 blocks.py:243(mgr_locs)
#         2    0.000    0.000    0.000    0.000 range.py:148(_simple_new)
#         4    0.000    0.000    0.000    0.000 dtypes.py:717(construct_from_string)
#        60    0.000    0.000    0.000    0.000 common.py:209(classes)
#         1    0.000    0.000    0.000    0.000 {method 'max' of 'numpy.ndarray' objects}
#        11    0.000    0.000    0.000    0.000 glpk_interface.py:319(_get_expression)
#         3    0.000    0.000    0.000    0.000 range.py:181(_data)
#         7    0.000    0.000    0.000    0.000 base.py:613(_get_attributes_dict)
#         4    0.000    0.000    0.000    0.000 common.py:1063(is_unsigned_integer_dtype)
#         1    0.000    0.000    0.000    0.000 model.py:863(add_cons_vars)
#         8    0.000    0.000    0.000    0.000 managers.py:1585(internal_values)
#         2    0.000    0.000    0.000    0.000 uuid.py:106(__init__)
#         9    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:416(parent)
#         1    0.000    0.000    0.000    0.000 solver.py:79(_valid_atoms)
#         1    0.000    0.000    0.000    0.000 solver.py:269(add_cons_vars_to_problem)
#         6    0.000    0.000    0.000    0.000 generic.py:162(__init__)
#        19    0.000    0.000    0.000    0.000 common.py:219(<lambda>)
#         2    0.000    0.000    0.000    0.000 common.py:711(is_string_dtype)
#        76    0.000    0.000    0.000    0.000 reaction.py:190(_check_bounds)
#         1    0.000    0.000    0.000    0.000 range.py:196(_int64index)
#         6    0.000    0.000    0.000    0.000 base.py:3901(values)
#         3    0.000    0.000    0.000    0.000 interface.py:377(_validate_optimization_expression_name)
#        37    0.000    0.000    0.000    0.000 managers.py:1523(_block)
#         2    0.000    0.000    0.000    0.000 base.py:729(__array__)
#         3    0.000    0.000    0.000    0.000 dtypes.py:866(construct_from_string)
#         1    0.000    0.000    0.000    0.000 {built-in method pandas._libs.missing.isnaobj}
#         1    0.000    0.000    0.000    0.000 _methods.py:28(_amax)
#         1    0.000    0.000    0.000    0.000 base.py:916(to_numpy)
#         3    0.000    0.000    0.000    0.000 dtypes.py:1040(construct_from_string)
#         4    0.000    0.000    0.000    0.000 {built-in method pandas._libs.lib.is_datetime_array}
#         1    0.000    0.000    0.000    0.000 {method 'all' of 'numpy.ndarray' objects}
#        10    0.000    0.000    0.000    0.000 {built-in method numpy.seterrobj}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.sorted}
#         1    0.000    0.000    0.000    0.000 interface.py:1489(_add_variables)
#         7    0.000    0.000    0.000    0.000 base.py:617(<dictcomp>)
#        16    0.000    0.000    0.000    0.000 typing.py:889(__extrahook__)
#         1    0.000    0.000    0.000    0.000 interface.py:461(_canonicalize)
#         3    0.000    0.000    0.000    0.000 generic.py:400(_get_axis_number)
#        17    0.000    0.000    0.000    0.000 base.py:723(__len__)
#         2    0.000    0.000    0.000    0.000 common.py:741(condition)
#         3    0.000    0.000    0.000    0.000 common.py:862(is_dtype_equal)
#         4    0.000    0.000    0.000    0.000 common.py:1253(is_timedelta64_ns_dtype)
#         9    0.000    0.000    0.000    0.000 {pandas._libs.lib.values_from_object}
#         1    0.000    0.000    0.000    0.000 interface.py:1340(add)
#         2    0.000    0.000    0.000    0.000 {method 'expand' of 'symengine.lib.symengine_wrapper.Basic' objects}
#         2    0.000    0.000    0.000    0.000 series.py:720(__len__)
#         1    0.000    0.000    0.000    0.000 series.py:3146(_try_kind_sort)
#         3    0.000    0.000    0.000    0.000 numpy_.py:165(__array__)
#        12    0.000    0.000    0.000    0.000 base.py:700(_reset_identity)
#         4    0.000    0.000    0.000    0.000 nanops.py:65(<genexpr>)
#         7    0.000    0.000    0.000    0.000 {pandas._libs.algos.ensure_object}
#         4    0.000    0.000    0.000    0.000 common.py:1203(is_datetime64_ns_dtype)
#         5    0.000    0.000    0.000    0.000 _ufunc_config.py:437(__init__)
#         1    0.000    0.000    0.000    0.000 re.py:231(compile)
#         3    0.000    0.000    0.000    0.000 model.py:900(problem)
#         1    0.000    0.000    0.000    0.000 glpk_interface.py:345(direction)
#         1    0.000    0.000    0.000    0.000 container.py:168(append)
#         4    0.000    0.000    0.000    0.000 cast.py:1264(construct_1d_ndarray_preserving_na)
#         2    0.000    0.000    0.000    0.000 {pandas._libs.lib.infer_datetimelike_array}
#         1    0.000    0.000    0.000    0.000 _methods.py:47(_all)
#         1    0.000    0.000    0.000    0.000 symbolics.py:77(__init__)
#        29    0.000    0.000    0.000    0.000 blocks.py:343(dtype)
#         1    0.000    0.000    0.000    0.000 re.py:286(_compile)
#         1    0.000    0.000    0.000    0.000 interface.py:1377(remove)
#         7    0.000    0.000    0.000    0.000 series.py:460(name)
#         1    0.000    0.000    0.000    0.000 __init__.py:81(get_op_result_name)
#         4    0.000    0.000    0.000    0.000 common.py:180(ensure_python_int)
#        19    0.000    0.000    0.000    0.000 common.py:214(classes_and_not_datetimelike)
#         1    0.000    0.000    0.000    0.000 {method 'argsort' of 'numpy.ndarray' objects}
#         6    0.000    0.000    0.000    0.000 {method 'view' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.000    0.000 _internal.py:865(npy_ctypes_check)
#         2    0.000    0.000    0.000    0.000 uuid.py:226(__str__)
#        26    0.000    0.000    0.000    0.000 _collections_abc.py:302(__subclasshook__)
#         3    0.000    0.000    0.000    0.000 {method 'match' of '_sre.SRE_Pattern' objects}
#        13    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x9d12c0}
#         1    0.000    0.000    0.000    0.000 interface.py:137(__validate_variable_name)
#         2    0.000    0.000    0.000    0.000 managers.py:325(__len__)
#         2    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.arange}
#         1    0.000    0.000    0.000    0.000 __init__.py:1298(info)
#        13    0.000    0.000    0.000    0.000 _collections_abc.py:367(__subclasshook__)
#         3    0.000    0.000    0.000    0.000 _weakrefset.py:36(__init__)
#         2    0.000    0.000    0.000    0.000 {built-in method from_bytes}
#         1    0.000    0.000    0.000    0.000 dictlist.py:20(__init__)
#         6    0.000    0.000    0.000    0.000 series.py:443(_set_subtyp)
#         6    0.000    0.000    0.000    0.000 blocks.py:131(_check_ndim)
#         1    0.000    0.000    0.000    0.000 generic.py:5145(__finalize__)
#         3    0.000    0.000    0.000    0.000 nanops.py:58(check)
#        20    0.000    0.000    0.000    0.000 {built-in method numpy.geterrobj}
#         9    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#        39    0.000    0.000    0.000    0.000 {method 'isspace' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#         1    0.000    0.000    0.000    0.000 model.py:1228(__enter__)
#         1    0.000    0.000    0.000    0.000 glpk_interface.py:119(type)
#         6    0.000    0.000    0.000    0.000 {built-in method swiglpk._swiglpk.glp_set_obj_coef}
#         3    0.000    0.000    0.000    0.000 interface.py:1175(interface)
#         3    0.000    0.000    0.000    0.000 interface.py:1191(<lambda>)
#         2    0.000    0.000    0.000    0.000 sparse.py:223(construct_from_string)
#         3    0.000    0.000    0.000    0.000 base.py:4118(_coerce_to_ndarray)
#         3    0.000    0.000    0.000    0.000 nanops.py:340(_na_ok_dtype)
#         2    0.000    0.000    0.000    0.000 inference.py:386(is_hashable)
#         2    0.000    0.000    0.000    0.000 inference.py:120(is_iterator)
#         1    0.000    0.000    0.000    0.000 common.py:1553(is_string_like_dtype)
#         5    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#         3    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#         8    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 context.py:20(__call__)
#         1    0.000    0.000    0.000    0.000 {built-in method swiglpk._swiglpk.glp_set_col_name}
#         8    0.000    0.000    0.000    0.000 interface.py:444(problem)
#         1    0.000    0.000    0.000    0.000 interface.py:124(__test_valid_upper_bound)
#         1    0.000    0.000    0.000    0.000 symbolics.py:71(__new__)
#         1    0.000    0.000    0.000    0.000 interface.py:111(__test_valid_lower_bound)
#         2    0.000    0.000    0.000    0.000 util.py:183(is_numeric)
#         8    0.000    0.000    0.000    0.000 blocks.py:207(internal_values)
#         1    0.000    0.000    0.000    0.000 _validators.py:231(validate_bool_kwarg)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:74(<dictcomp>)
#         2    0.000    0.000    0.000    0.000 _collections_abc.py:271(__subclasshook__)
#         2    0.000    0.000    0.000    0.000 _collections_abc.py:349(__subclasshook__)
#         2    0.000    0.000    0.000    0.000 {method 'count' of 'list' objects}
#        14    0.000    0.000    0.000    0.000 {method '__subclasshook__' of 'object' objects}
#         2    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'search' of '_sre.SRE_Pattern' objects}
#         2    0.000    0.000    0.000    0.000 solver.py:96(<genexpr>)
#         1    0.000    0.000    0.000    0.000 {built-in method swiglpk._swiglpk.glp_add_cols}
#         1    0.000    0.000    0.000    0.000 container.py:58(_check_for_name_attribute)
#         6    0.000    0.000    0.000    0.000 blocks.py:239(mgr_locs)
#         2    0.000    0.000    0.000    0.000 range.py:652(__len__)
#         2    0.000    0.000    0.000    0.000 nanops.py:173(_get_fill_value)
#         1    0.000    0.000    0.000    0.000 common.py:150(cast_scalar_indexer)
#         4    0.000    0.000    0.000    0.000 common.py:1281(<lambda>)
#         5    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_integer}
#         1    0.000    0.000    0.000    0.000 {method 'copy' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {method 'setdefault' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 boundary_types.py:49(<listcomp>)
#         1    0.000    0.000    0.000    0.000 context.py:15(__init__)
#         3    0.000    0.000    0.000    0.000 {built-in method swiglpk._swiglpk.glp_set_obj_dir}
#         1    0.000    0.000    0.000    0.000 {built-in method swiglpk._swiglpk.glp_set_col_kind}
#         1    0.000    0.000    0.000    0.000 glpk_interface.py:77(_glpk_validate_id)
#         1    0.000    0.000    0.000    0.000 interface.py:248(type)
#         5    0.000    0.000    0.000    0.000 interface.py:902(direction)
#         1    0.000    0.000    0.000    0.000 container.py:63(__len__)
#         2    0.000    0.000    0.000    0.000 range.py:170(_validate_dtype)
#         1    0.000    0.000    0.000    0.000 range.py:236(start)
#         1    0.000    0.000    0.000    0.000 numeric.py:134(is_all_dates)
#         2    0.000    0.000    0.000    0.000 base.py:526(<genexpr>)
#         1    0.000    0.000    0.000    0.000 base.py:747(dtype)
#         2    0.000    0.000    0.000    0.000 common.py:185(_all_none)
#         2    0.000    0.000    0.000    0.000 function.py:42(__call__)
#         1    0.000    0.000    0.000    0.000 common.py:1582(<lambda>)
#         2    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_bool}
#         1    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 sre_compile.py:539(isstring)
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         1    0.000    0.000    0.000    0.000 interface.py:243(type)
#         1    0.000    0.000    0.000    0.000 interface.py:907(direction)
#         1    0.000    0.000    0.000    0.000 container.py:66(__contains__)
#         2    0.000    0.000    0.000    0.000 series.py:399(_constructor)
#         2    0.000    0.000    0.000    0.000 managers.py:236(items)
#         1    0.000    0.000    0.000    0.000 range.py:259(stop)
#         1    0.000    0.000    0.000    0.000 range.py:282(step)
#         1    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_float}
#         1    0.000    0.000    0.000    0.000 {built-in method pandas._libs.missing.checknull}
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:2787(_prod_dispatcher)
#         1    0.000    0.000    0.000    0.000 numeric.py:2295(_array_equal_dispatcher)

# %% [markdown]
# ## Profiling of old test
# As, I can't see anything relevant, I will compare it with the performance of the old test

# %%
cProfile.run('test_old(model)', 'oldstats')
p_old = pstats.Stats('oldstats')
p_old.strip_dirs().sort_stats(2).print_stats()
# Out:
# Thu Nov  7 10:46:08 2019    oldstats
#
#          1478970 function calls (1457416 primitive calls) in 3.134 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    3.134    3.134 {built-in method builtins.exec}
#         1    0.000    0.000    3.134    3.134 <string>:1(<module>)
#         1    0.007    0.007    3.134    3.134 <ipython-input-2-2558f62ab766>:46(test_old)
#       342    0.002    0.000    2.428    0.007 <ipython-input-2-2558f62ab766>:17(run_fba)
#       342    0.002    0.000    2.323    0.007 model.py:1020(slim_optimize)
#       342    0.001    0.000    2.317    0.007 interface.py:1454(optimize)
#       342    0.002    0.000    2.315    0.007 glpk_interface.py:700(_optimize)
#       554    0.004    0.000    2.225    0.004 glpk_interface.py:674(_run_glp_simplex)
#       554    2.219    0.004    2.219    0.004 {built-in method swiglpk._swiglpk.glp_simplex}
#       342    0.001    0.000    0.381    0.001 model.py:1240(__exit__)
#       342    0.003    0.000    0.380    0.001 context.py:32(reset)
#       684    0.011    0.000    0.370    0.001 glpk_interface.py:615(objective)
#       342    0.002    0.000    0.351    0.001 solver.py:161(reset)
#       684    0.001    0.000    0.320    0.000 interface.py:456(variables)
#      3078    0.003    0.000    0.317    0.000 interface.py:451(expression)
#      3078    0.008    0.000    0.314    0.000 glpk_interface.py:319(_get_expression)
#       342    0.002    0.000    0.300    0.001 glpk_interface.py:329(<listcomp>)
#      1026    0.134    0.000    0.295    0.000 glpk_interface.py:323(term_generator)
#       342    0.004    0.000    0.291    0.001 model.py:529(add_boundary)
#       342    0.006    0.000    0.218    0.001 model.py:629(add_reactions)
#       342    0.011    0.000    0.199    0.001 model.py:980(_populate_solver)
#    329004    0.067    0.000    0.113    0.000 interface.py:439(problem)
#       342    0.002    0.000    0.101    0.000 model.py:1140(objective)
#       342    0.008    0.000    0.096    0.000 solver.py:99(set_objective)
#       212    0.086    0.000    0.086    0.000 {built-in method swiglpk._swiglpk.glp_adv_basis}
#      6650    0.019    0.000    0.071    0.000 interface.py:1417(update)
#       342    0.018    0.000    0.070    0.000 glpk_interface.py:262(set_linear_coefficients)
#       342    0.005    0.000    0.066    0.000 reaction.py:763(add_metabolites)
#       342    0.001    0.000    0.057    0.000 species.py:41(copy)
# 17415/342    0.024    0.000    0.056    0.000 copy.py:132(deepcopy)
# 341496/340812    0.051    0.000    0.052    0.000 {built-in method builtins.getattr}
#    321480    0.052    0.000    0.052    0.000 {built-in method swiglpk._swiglpk.glp_get_obj_coef}
#   684/342    0.003    0.000    0.050    0.000 copy.py:268(_reconstruct)
#       684    0.001    0.000    0.046    0.000 model.py:863(add_cons_vars)
#       684    0.003    0.000    0.045    0.000 solver.py:269(add_cons_vars_to_problem)
#  1026/342    0.006    0.000    0.043    0.000 copy.py:236(_deepcopy_dict)
#  1368/684    0.003    0.000    0.041    0.000 interface.py:1340(add)
#       684    0.003    0.000    0.035    0.000 glpk_interface.py:310(__init__)
#       342    0.005    0.000    0.029    0.000 glpk_interface.py:734(_remove_variables)
#       684    0.002    0.000    0.028    0.000 interface.py:869(__init__)
#       418    0.003    0.000    0.027    0.000 reaction.py:197(update_variable_bounds)
#       684    0.004    0.000    0.026    0.000 interface.py:411(__init__)
#     11019    0.013    0.000    0.026    0.000 glpk_interface.py:90(_index)
#         1    0.000    0.000    0.026    0.026 <ipython-input-2-2558f62ab766>:1(open_exchanges)
#       684    0.001    0.000    0.022    0.000 model.py:933(constraints)
#       684    0.001    0.000    0.021    0.000 interface.py:1206(constraints)
#         1    0.000    0.000    0.020    0.020 model.py:956(exchanges)
#         1    0.000    0.000    0.020    0.020 boundary_types.py:132(find_boundary_types)
#       342    0.001    0.000    0.018    0.000 dictlist.py:234(__isub__)
#       684    0.005    0.000    0.018    0.000 interface.py:1188(objective)
#       342    0.004    0.000    0.017    0.000 glpk_interface.py:724(_add_variables)
#       342    0.001    0.000    0.017    0.000 dictlist.py:363(remove)
#       760    0.002    0.000    0.015    0.000 reaction.py:147(reverse_variable)
#       342    0.014    0.000    0.015    0.000 dictlist.py:345(pop)
#       684    0.002    0.000    0.014    0.000 glpk_interface.py:86(__init__)
#      1026    0.005    0.000    0.014    0.000 swiglpk.py:1695(__init__)
#       684    0.005    0.000    0.012    0.000 uuid.py:580(uuid1)
#     16678    0.006    0.000    0.012    0.000 {built-in method builtins.isinstance}
#       684    0.009    0.000    0.012    0.000 interface.py:471(is_Linear)
#       684    0.004    0.000    0.012    0.000 interface.py:160(__init__)
#      1520    0.005    0.000    0.011    0.000 glpk_interface.py:777(_glpk_set_col_bounds)
#       836    0.002    0.000    0.011    0.000 glpk_interface.py:114(set_bounds)
#         1    0.000    0.000    0.011    0.011 boundary_types.py:26(find_external_compartment)
#      1102    0.005    0.000    0.011    0.000 reaction.py:109(reverse_id)
#      7257    0.011    0.000    0.011    0.000 container.py:80(__getitem__)
#      1368    0.011    0.000    0.011    0.000 {method 'atoms' of 'symengine.lib.symengine_wrapper.Basic' objects}
#     11019    0.010    0.000    0.010    0.000 {built-in method swiglpk._swiglpk.glp_find_col}
#       683    0.002    0.000    0.010    0.000 container.py:112(__delitem__)
#       342    0.004    0.000    0.010    0.000 glpk_interface.py:275(<dictcomp>)
#      1862    0.002    0.000    0.010    0.000 model.py:917(variables)
#       684    0.002    0.000    0.009    0.000 expression_parsing.py:21(parse_optimization_expression)
#      1075    0.003    0.000    0.009    0.000 copy.py:210(_deepcopy_list)
#       760    0.002    0.000    0.009    0.000 reaction.py:132(forward_variable)
# 58858/57468    0.007    0.000    0.008    0.000 {built-in method builtins.len}
#      2792    0.004    0.000    0.008    0.000 abc.py:180(__instancecheck__)
#      1862    0.001    0.000    0.008    0.000 interface.py:1200(variables)
#       418    0.001    0.000    0.007    0.000 context.py:60(wrapper)
#       342    0.003    0.000    0.007    0.000 interface.py:893(_canonicalize)
#       684    0.005    0.000    0.007    0.000 dictlist.py:175(extend)
#  1368/684    0.003    0.000    0.007    0.000 interface.py:1377(remove)
#       683    0.006    0.000    0.007    0.000 container.py:120(_reindex)
#     39064    0.006    0.000    0.006    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.006    0.006 dictlist.py:94(query)
#         1    0.000    0.000    0.006    0.006 dictlist.py:201(_extend_nocheck)
#       343    0.002    0.000    0.006    0.000 dictlist.py:20(__init__)
#       342    0.002    0.000    0.006    0.000 glpk_interface.py:365(set_linear_coefficients)
#        77    0.001    0.000    0.006    0.000 dictlist.py:147(<genexpr>)
#       342    0.002    0.000    0.006    0.000 interface.py:1489(_add_variables)
#      8854    0.004    0.000    0.006    0.000 object.py:25(id)
#       684    0.006    0.000    0.006    0.000 expression_parsing.py:67(_parse_linear_expression)
#        76    0.000    0.000    0.005    0.000 reaction.py:296(bounds)
#       684    0.002    0.000    0.005    0.000 swiglpk.py:1730(__init__)
#      1776    0.002    0.000    0.005    0.000 reaction.py:542(boundary)
#       342    0.005    0.000    0.005    0.000 {built-in method swiglpk._swiglpk.glp_del_cols}
#       469    0.000    0.000    0.005    0.000 boundary_types.py:160(<lambda>)
#       684    0.003    0.000    0.005    0.000 uuid.py:106(__init__)
#       469    0.002    0.000    0.005    0.000 boundary_types.py:85(is_boundary_type)
#         3    0.000    0.000    0.005    0.002 model.py:949(boundary)
#         3    0.001    0.000    0.005    0.002 model.py:954(<listcomp>)
#      4711    0.002    0.000    0.004    0.000 swiglpk.py:1707(__setitem__)
#       342    0.001    0.000    0.004    0.000 glpk_interface.py:334(value)
#      2646    0.003    0.000    0.004    0.000 six.py:586(iteritems)
#      1710    0.004    0.000    0.004    0.000 swiglpk.py:77(_swig_getattr)
#       684    0.002    0.000    0.004    0.000 container.py:168(append)
#      1026    0.001    0.000    0.004    0.000 swiglpk.py:1692(<lambda>)
#         1    0.000    0.000    0.004    0.004 base.py:1304(value_counts)
#         1    0.000    0.000    0.004    0.004 algorithms.py:695(value_counts)
#       684    0.001    0.000    0.004    0.000 glpk_interface.py:804(_glpk_is_mip)
#       342    0.000    0.000    0.004    0.000 dictlist.py:262(__iadd__)
#      1368    0.002    0.000    0.004    0.000 dictlist.py:315(__contains__)
#      3856    0.004    0.000    0.004    0.000 _weakrefset.py:70(__contains__)
#      1710    0.001    0.000    0.004    0.000 swiglpk.py:73(_swig_setattr)
#      1368    0.001    0.000    0.003    0.000 copy.py:273(<genexpr>)
#       684    0.003    0.000    0.003    0.000 {built-in method swiglpk._swiglpk.glp_get_num_int}
#      2785    0.003    0.000    0.003    0.000 copy.py:252(_keep_alive)
#       684    0.003    0.000    0.003    0.000 symbolics.py:97(mul)
#      3542    0.003    0.000    0.003    0.000 {built-in method builtins.hasattr}
#         6    0.000    0.000    0.003    0.001 series.py:194(__init__)
#       684    0.002    0.000    0.003    0.000 interface.py:137(__validate_variable_name)
#      1026    0.001    0.000    0.003    0.000 swiglpk.py:1690(<lambda>)
#      4028    0.002    0.000    0.003    0.000 swiglpk.py:1742(__setitem__)
#       684    0.003    0.000    0.003    0.000 {built-in method builtins.sorted}
#     17513    0.003    0.000    0.003    0.000 interface.py:182(name)
#      2802    0.002    0.000    0.003    0.000 reaction.py:414(metabolites)
#       342    0.001    0.000    0.003    0.000 dictlist.py:64(get_by_any)
#     23327    0.003    0.000    0.003    0.000 {built-in method builtins.id}
#       684    0.002    0.000    0.003    0.000 {method '__reduce_ex__' of 'object' objects}
#       684    0.003    0.000    0.003    0.000 symbolics.py:77(__init__)
#       684    0.001    0.000    0.003    0.000 glpk_interface.py:219(_index)
#       342    0.002    0.000    0.003    0.000 symbolics.py:90(add)
#      3344    0.001    0.000    0.002    0.000 swiglpk.py:1739(__getitem__)
#      1710    0.002    0.000    0.002    0.000 swiglpk.py:54(_swig_setattr_nondynamic)
#       342    0.002    0.000    0.002    0.000 glpk_interface.py:345(direction)
#      3344    0.001    0.000    0.002    0.000 swiglpk.py:1704(__getitem__)
#      1026    0.001    0.000    0.002    0.000 model.py:900(problem)
#       684    0.002    0.000    0.002    0.000 uuid.py:226(__str__)
#      4711    0.002    0.000    0.002    0.000 {built-in method swiglpk._swiglpk.intArray___setitem__}
#       684    0.002    0.000    0.002    0.000 __init__.py:47(create_string_buffer)
#     11712    0.002    0.000    0.002    0.000 {method 'append' of 'list' objects}
#      2128    0.002    0.000    0.002    0.000 context.py:39(get_context)
#       342    0.001    0.000    0.002    0.000 dictlist.py:294(index)
#         1    0.000    0.000    0.002    0.002 series.py:3023(sort_values)
#       342    0.000    0.000    0.002    0.000 dictlist.py:92(<listcomp>)
#      1102    0.002    0.000    0.002    0.000 {built-in method _hashlib.openssl_md5}
#      9386    0.002    0.000    0.002    0.000 model.py:124(solver)
#       342    0.001    0.000    0.002    0.000 dictlist.py:80(get_item)
#       342    0.001    0.000    0.002    0.000 interface.py:461(_canonicalize)
#     14630    0.002    0.000    0.002    0.000 copy.py:190(_deepcopy_atomic)
#       836    0.001    0.000    0.002    0.000 interface.py:229(set_bounds)
#      4028    0.002    0.000    0.002    0.000 {built-in method swiglpk._swiglpk.doubleArray___setitem__}
#      1710    0.001    0.000    0.002    0.000 context.py:20(__call__)
#         7    0.000    0.000    0.002    0.000 base.py:4262(__getitem__)
#      1102    0.002    0.000    0.002    0.000 {method 'hexdigest' of '_hashlib.HASH' objects}
#       684    0.001    0.000    0.002    0.000 glpk_interface.py:119(type)
#       684    0.000    0.000    0.001    0.000 swiglpk.py:1727(<lambda>)
#      3144    0.001    0.000    0.001    0.000 {method 'copy' of 'dict' objects}
#       684    0.001    0.000    0.001    0.000 {built-in method from_bytes}
#       684    0.001    0.000    0.001    0.000 symbolics.py:71(__new__)
#       6/5    0.000    0.000    0.001    0.000 base.py:277(__new__)
#       342    0.001    0.000    0.001    0.000 model.py:642(existing_filter)
#       342    0.001    0.000    0.001    0.000 reaction.py:72(__init__)
#       684    0.001    0.000    0.001    0.000 {built-in method swiglpk._swiglpk.glp_set_col_name}
#      2736    0.001    0.000    0.001    0.000 {built-in method swiglpk._swiglpk.glp_set_obj_coef}
#       684    0.000    0.000    0.001    0.000 swiglpk.py:1725(<lambda>)
#      3344    0.001    0.000    0.001    0.000 {built-in method swiglpk._swiglpk.glp_get_col_name}
#      3344    0.001    0.000    0.001    0.000 {built-in method swiglpk._swiglpk.doubleArray___getitem__}
#      3344    0.001    0.000    0.001    0.000 {built-in method swiglpk._swiglpk.intArray___getitem__}
#       342    0.001    0.000    0.001    0.000 model.py:1228(__enter__)
#       342    0.001    0.000    0.001    0.000 species.py:32(__getstate__)
#         6    0.000    0.000    0.001    0.000 construction.py:630(sanitize_array)
#       684    0.001    0.000    0.001    0.000 util.py:19(__getitem__)
#      6080    0.001    0.000    0.001    0.000 glpk_interface.py:206(problem)
#       684    0.001    0.000    0.001    0.000 {method 'expand' of 'symengine.lib.symengine_wrapper.Basic' objects}
#      5396    0.001    0.000    0.001    0.000 {method 'items' of 'dict' objects}
#      1026    0.001    0.000    0.001    0.000 interface.py:1175(interface)
#         1    0.000    0.000    0.001    0.001 algorithms.py:772(_value_counts_arraylike)
#      2052    0.001    0.000    0.001    0.000 {method 'pop' of 'list' objects}
#       212    0.000    0.000    0.001    0.000 __init__.py:1286(debug)
#      1026    0.001    0.000    0.001    0.000 {built-in method swiglpk._swiglpk.new_intArray}
#      1520    0.001    0.000    0.001    0.000 {built-in method swiglpk._swiglpk.glp_set_col_bnds}
#      2646    0.001    0.000    0.001    0.000 {built-in method builtins.iter}
#      1367    0.001    0.000    0.001    0.000 container.py:63(__len__)
#       684    0.001    0.000    0.001    0.000 {built-in method swiglpk._swiglpk.glp_find_row}
#      1026    0.001    0.000    0.001    0.000 dictlist.py:56(get_by_id)
#       684    0.001    0.000    0.001    0.000 container.py:66(__contains__)
#        82    0.000    0.000    0.001    0.000 base.py:231(is_dtype)
#       684    0.000    0.000    0.001    0.000 container.py:58(_check_for_name_attribute)
#       342    0.001    0.000    0.001    0.000 {built-in method swiglpk._swiglpk.glp_set_mat_row}
#         1    0.000    0.000    0.001    0.001 __init__.py:1126(wrapper)
#      8208    0.001    0.000    0.001    0.000 {method 'isspace' of 'str' objects}
#      2736    0.001    0.000    0.001    0.000 interface.py:444(problem)
#       213    0.000    0.000    0.001    0.000 __init__.py:1544(isEnabledFor)
#      3800    0.001    0.000    0.001    0.000 reaction.py:551(model)
#         2    0.000    0.000    0.001    0.000 range.py:662(__getitem__)
#      4864    0.001    0.000    0.001    0.000 interface.py:197(lb)
#      1102    0.001    0.000    0.001    0.000 {method 'encode' of 'str' objects}
#      3420    0.001    0.000    0.001    0.000 glpk_interface.py:611(objective)
#       342    0.001    0.000    0.001    0.000 model.py:1152(objective_direction)
#         2    0.000    0.000    0.001    0.000 model.py:211(compartments)
#       297    0.000    0.000    0.001    0.000 reaction.py:726(reactants)
#         6    0.000    0.000    0.001    0.000 managers.py:1470(__init__)
#         2    0.001    0.000    0.001    0.000 model.py:213(<dictcomp>)
#         3    0.000    0.000    0.001    0.000 numeric.py:82(_shallow_copy)
#       691    0.001    0.000    0.001    0.000 {method 'update' of 'dict' objects}
#       376    0.000    0.000    0.001    0.000 generic.py:7(_check)
#       342    0.000    0.000    0.001    0.000 object.py:53(__str__)
#         3    0.000    0.000    0.001    0.000 base.py:652(_shallow_copy_with_infer)
#       297    0.000    0.000    0.001    0.000 reaction.py:731(products)
#         2    0.000    0.000    0.001    0.000 series.py:4051(_reduce)
#         6    0.000    0.000    0.001    0.000 blocks.py:3241(make_block)
#      1368    0.001    0.000    0.001    0.000 {built-in method swiglpk._swiglpk.glp_get_num_cols}
#       342    0.001    0.000    0.001    0.000 glpk_interface.py:273(<dictcomp>)
#       342    0.001    0.000    0.001    0.000 object.py:43(__getstate__)
#       342    0.001    0.000    0.001    0.000 {built-in method swiglpk._swiglpk.glp_get_mat_row}
#        79    0.000    0.000    0.001    0.000 common.py:1886(_is_dtype_type)
#       684    0.000    0.000    0.001    0.000 glpk_interface.py:77(_glpk_validate_id)
#       684    0.001    0.000    0.001    0.000 {built-in method swiglpk._swiglpk.glp_add_cols}
#         2    0.000    0.000    0.001    0.000 range.py:410(_shallow_copy)
#      3344    0.001    0.000    0.001    0.000 interface.py:213(ub)
#       342    0.001    0.000    0.001    0.000 {method 'as_coefficients_dict' of 'symengine.lib.symengine_wrapper.Basic' objects}
#      1102    0.001    0.000    0.001    0.000 {method 'join' of 'str' objects}
#       684    0.001    0.000    0.001    0.000 {built-in method swiglpk._swiglpk.new_doubleArray}
#         4    0.000    0.000    0.001    0.000 construction.py:759(_try_cast)
#       342    0.000    0.000    0.001    0.000 model.py:1118(objective)
#      1026    0.001    0.000    0.001    0.000 {built-in method swiglpk._swiglpk.glp_set_obj_dir}
#       368    0.001    0.000    0.001    0.000 {method 'format' of 'str' objects}
#     19/13    0.000    0.000    0.001    0.000 _asarray.py:16(asarray)
#       393    0.001    0.000    0.001    0.000 boundary_types.py:112(<listcomp>)
#      1038    0.001    0.000    0.001    0.000 {built-in method __new__ of type object at 0x9d12c0}
#         5    0.000    0.000    0.001    0.000 base.py:5707(ensure_index)
#       342    0.000    0.000    0.001    0.000 copyreg.py:87(__newobj__)
#       554    0.001    0.000    0.001    0.000 {built-in method swiglpk._swiglpk.glp_get_status}
#         6    0.000    0.000    0.001    0.000 blocks.py:3195(get_block_type)
#       684    0.000    0.000    0.000    0.000 interface.py:1191(<lambda>)
#       342    0.000    0.000    0.000    0.000 dictlist.py:390(__getitem__)
#     27/21    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#         1    0.000    0.000    0.000    0.000 base.py:1243(to_series)
#      2052    0.000    0.000    0.000    0.000 interface.py:902(direction)
#         1    0.000    0.000    0.000    0.000 algorithms.py:61(_ensure_data)
#        59    0.000    0.000    0.000    0.000 common.py:1743(is_extension_array_dtype)
#        61    0.000    0.000    0.000    0.000 dtypes.py:83(find)
#       684    0.000    0.000    0.000    0.000 interface.py:248(type)
#        32    0.000    0.000    0.000    0.000 common.py:539(is_datetime64tz_dtype)
#       342    0.000    0.000    0.000    0.000 object.py:11(__init__)
#       684    0.000    0.000    0.000    0.000 {built-in method swiglpk._swiglpk.glp_set_col_kind}
#         5    0.000    0.000    0.000    0.000 common.py:1466(needs_i8_conversion)
#       836    0.000    0.000    0.000    0.000 {built-in method math.isinf}
#         1    0.000    0.000    0.000    0.000 generic.py:11546(stat_func)
#       213    0.000    0.000    0.000    0.000 __init__.py:1530(getEffectiveLevel)
#         3    0.000    0.000    0.000    0.000 missing.py:48(isna)
#         3    0.000    0.000    0.000    0.000 missing.py:128(_isna_new)
#         1    0.000    0.000    0.000    0.000 generic.py:11594(stat_func)
#        36    0.000    0.000    0.000    0.000 common.py:2020(pandas_dtype)
#         3    0.000    0.000    0.000    0.000 series.py:886(__array__)
#       934    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#       684    0.000    0.000    0.000    0.000 interface.py:111(__test_valid_lower_bound)
#       684    0.000    0.000    0.000    0.000 {method 'count' of 'list' objects}
#         6    0.000    0.000    0.000    0.000 cast.py:986(maybe_cast_to_datetime)
#        26    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_scalar}
#       469    0.000    0.000    0.000    0.000 dictlist.py:124(select_attribute)
#        19    0.000    0.000    0.000    0.000 common.py:608(is_period_dtype)
#       689    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 nanops.py:62(_f)
#         4    0.000    0.000    0.000    0.000 base.py:831(array)
#         2    0.000    0.000    0.000    0.000 missing.py:219(_isna_ndarraylike)
#        24    0.000    0.000    0.000    0.000 common.py:678(is_categorical_dtype)
#         7    0.000    0.000    0.000    0.000 common.py:1284(is_datetime_or_timedelta_dtype)
#        19    0.000    0.000    0.000    0.000 dtypes.py:912(is_dtype)
#        14    0.000    0.000    0.000    0.000 common.py:1619(is_bool_dtype)
#       684    0.000    0.000    0.000    0.000 interface.py:124(__test_valid_upper_bound)
#       684    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#       684    0.000    0.000    0.000    0.000 interface.py:377(_validate_optimization_expression_name)
#       684    0.000    0.000    0.000    0.000 interface.py:243(type)
#       342    0.000    0.000    0.000    0.000 context.py:15(__init__)
#         1    0.000    0.000    0.000    0.000 nanops.py:96(f)
#       342    0.000    0.000    0.000    0.000 interface.py:907(direction)
#         6    0.000    0.000    0.000    0.000 common.py:99(is_bool_indexer)
#       468    0.000    0.000    0.000    0.000 reaction.py:964(compartments)
#        18    0.000    0.000    0.000    0.000 common.py:642(is_interval_dtype)
#       342    0.000    0.000    0.000    0.000 model.py:1149(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 nanops.py:469(nansum)
#         1    0.000    0.000    0.000    0.000 nanops.py:829(reduction)
#       836    0.000    0.000    0.000    0.000 interface.py:1482(_set_variable_bounds_on_problem)
#       684    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#        13    0.000    0.000    0.000    0.000 dtypes.py:1092(is_dtype)
#         1    0.000    0.000    0.000    0.000 __init__.py:1081(na_op)
#        13    0.000    0.000    0.000    0.000 _dtype.py:319(_name_get)
#         7    0.000    0.000    0.000    0.000 common.py:1163(is_datetime64_any_dtype)
#         5    0.000    0.000    0.000    0.000 {pandas._libs.lib.infer_dtype}
#         2    0.000    0.000    0.000    0.000 nanops.py:239(_get_values)
#      1026    0.000    0.000    0.000    0.000 swiglpk.py:1702(<lambda>)
#         4    0.000    0.000    0.000    0.000 cast.py:880(maybe_infer_to_datetimelike)
#       684    0.000    0.000    0.000    0.000 species.py:51(model)
#       342    0.000    0.000    0.000    0.000 {built-in method swiglpk._swiglpk.glp_get_obj_val}
#        10    0.000    0.000    0.000    0.000 common.py:357(is_categorical)
#         1    0.000    0.000    0.000    0.000 dictlist.py:52(_generate_index)
#       684    0.000    0.000    0.000    0.000 interface.py:429(name)
#        14    0.000    0.000    0.000    0.000 common.py:508(is_datetime64_dtype)
#         1    0.000    0.000    0.000    0.000 dictlist.py:54(<dictcomp>)
#        10    0.000    0.000    0.000    0.000 base.py:569(_simple_new)
#         2    0.000    0.000    0.000    0.000 cast.py:63(maybe_convert_platform)
#         6    0.000    0.000    0.000    0.000 series.py:416(_set_axis)
#         4    0.000    0.000    0.000    0.000 common.py:1684(is_extension_type)
#       469    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#        47    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:997(_handle_fromlist)
#        19    0.000    0.000    0.000    0.000 common.py:225(is_object_dtype)
#       342    0.000    0.000    0.000    0.000 reaction.py:791(<listcomp>)
#        14    0.000    0.000    0.000    0.000 common.py:577(is_timedelta64_dtype)
#         4    0.000    0.000    0.000    0.000 base.py:634(_shallow_copy)
#        10    0.000    0.000    0.000    0.000 _ufunc_config.py:39(seterr)
#         4    0.000    0.000    0.000    0.000 numpy_.py:122(__init__)
#         2    0.000    0.000    0.000    0.000 common.py:297(maybe_iterable_to_list)
#       342    0.000    0.000    0.000    0.000 model.py:167(tolerance)
#       297    0.000    0.000    0.000    0.000 reaction.py:729(<listcomp>)
#         6    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#       684    0.000    0.000    0.000    0.000 swiglpk.py:1737(<lambda>)
#        13    0.000    0.000    0.000    0.000 numerictypes.py:365(issubdtype)
#         3    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#        29    0.000    0.000    0.000    0.000 series.py:467(dtype)
#         1    0.000    0.000    0.000    0.000 generic.py:227(_validate_dtype)
#       297    0.000    0.000    0.000    0.000 reaction.py:734(<listcomp>)
#        16    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_list_like}
#         4    0.000    0.000    0.000    0.000 numpy_.py:39(__init__)
#         6    0.000    0.000    0.000    0.000 generic.py:5181(__setattr__)
#         3    0.000    0.000    0.000    0.000 numeric.py:47(__new__)
#         2    0.000    0.000    0.000    0.000 nanops.py:1187(_maybe_null_out)
#         6    0.000    0.000    0.000    0.000 blocks.py:120(__init__)
#        11    0.000    0.000    0.000    0.000 common.py:255(is_sparse)
#         4    0.000    0.000    0.000    0.000 cast.py:866(maybe_castable)
#         2    0.000    0.000    0.000    0.000 {pandas._libs.lib.maybe_convert_objects}
#         1    0.000    0.000    0.000    0.000 algorithms.py:167(_reconstruct_data)
#         5    0.000    0.000    0.000    0.000 _ufunc_config.py:441(__enter__)
#       342    0.000    0.000    0.000    0.000 interface.py:1212(status)
#       212    0.000    0.000    0.000    0.000 glpk_interface.py:455(presolve)
#         2    0.000    0.000    0.000    0.000 base.py:5801(default_index)
#        19    0.000    0.000    0.000    0.000 base.py:180(construct_from_string)
#        29    0.000    0.000    0.000    0.000 managers.py:1558(dtype)
#       100    0.000    0.000    0.000    0.000 boundary_types.py:43(<genexpr>)
#         1    0.000    0.000    0.000    0.000 common.py:1407(is_datetimelike_v_numeric)
#         3    0.000    0.000    0.000    0.000 common.py:240(asarray_tuplesafe)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(prod)
#        30    0.000    0.000    0.000    0.000 common.py:1850(_get_dtype)
#         1    0.000    0.000    0.000    0.000 {built-in method pandas._libs.hashtable.value_count_object}
#        26    0.000    0.000    0.000    0.000 numerictypes.py:293(issubclass_)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:2792(prod)
#         3    0.000    0.000    0.000    0.000 cast.py:1239(construct_1d_object_array_from_listlike)
#        60    0.000    0.000    0.000    0.000 common.py:211(<lambda>)
#         5    0.000    0.000    0.000    0.000 _ufunc_config.py:446(__exit__)
#         7    0.000    0.000    0.000    0.000 common.py:1006(is_signed_integer_dtype)
#         4    0.000    0.000    0.000    0.000 base.py:1884(is_all_dates)
#         2    0.000    0.000    0.000    0.000 {method 'sum' of 'numpy.ndarray' objects}
#         6    0.000    0.000    0.000    0.000 arrays.py:7(extract_array)
#         2    0.000    0.000    0.000    0.000 range.py:83(__new__)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:73(_wrapreduction)
#         2    0.000    0.000    0.000    0.000 nanops.py:345(_wrap_results)
#         1    0.000    0.000    0.000    0.000 cast.py:1306(maybe_cast_to_integer_array)
#         2    0.000    0.000    0.000    0.000 _methods.py:36(_sum)
#         8    0.000    0.000    0.000    0.000 common.py:951(is_integer_dtype)
#         7    0.000    0.000    0.000    0.000 common.py:1825(_is_dtype)
#         5    0.000    0.000    0.000    0.000 {built-in method numpy.empty}
#        10    0.000    0.000    0.000    0.000 _ufunc_config.py:139(geterr)
#         2    0.000    0.000    0.000    0.000 nanops.py:196(_maybe_get_mask)
#         6    0.000    0.000    0.000    0.000 common.py:1585(is_float_dtype)
#         9    0.000    0.000    0.000    0.000 series.py:453(name)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(array_equal)
#         8    0.000    0.000    0.000    0.000 series.py:559(_values)
#         2    0.000    0.000    0.000    0.000 blocks.py:2771(__init__)
#         1    0.000    0.000    0.000    0.000 generic.py:5145(__finalize__)
#        60    0.000    0.000    0.000    0.000 common.py:209(classes)
#         3    0.000    0.000    0.000    0.000 generic.py:400(_get_axis_number)
#        12    0.000    0.000    0.000    0.000 generic.py:5162(__getattr__)
#         4    0.000    0.000    0.000    0.000 dtypes.py:717(construct_from_string)
#         4    0.000    0.000    0.000    0.000 common.py:1063(is_unsigned_integer_dtype)
#         1    0.000    0.000    0.000    0.000 {built-in method pandas._libs.missing.isnaobj}
#         1    0.000    0.000    0.000    0.000 numeric.py:2299(array_equal)
#         2    0.000    0.000    0.000    0.000 common.py:711(is_string_dtype)
#         9    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:416(parent)
#         6    0.000    0.000    0.000    0.000 generic.py:162(__init__)
#         7    0.000    0.000    0.000    0.000 base.py:613(_get_attributes_dict)
#         2    0.000    0.000    0.000    0.000 base.py:729(__array__)
#         8    0.000    0.000    0.000    0.000 managers.py:1585(internal_values)
#         3    0.000    0.000    0.000    0.000 range.py:181(_data)
#         3    0.000    0.000    0.000    0.000 dtypes.py:866(construct_from_string)
#         3    0.000    0.000    0.000    0.000 dtypes.py:1040(construct_from_string)
#        19    0.000    0.000    0.000    0.000 common.py:219(<lambda>)
#         6    0.000    0.000    0.000    0.000 blocks.py:243(mgr_locs)
#         1    0.000    0.000    0.000    0.000 base.py:916(to_numpy)
#         1    0.000    0.000    0.000    0.000 {method 'max' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 range.py:148(_simple_new)
#         6    0.000    0.000    0.000    0.000 base.py:3901(values)
#        76    0.000    0.000    0.000    0.000 reaction.py:190(_check_bounds)
#         1    0.000    0.000    0.000    0.000 _methods.py:28(_amax)
#         1    0.000    0.000    0.000    0.000 range.py:196(_int64index)
#        17    0.000    0.000    0.000    0.000 base.py:723(__len__)
#         1    0.000    0.000    0.000    0.000 algorithms.py:199(_ensure_arraylike)
#         2    0.000    0.000    0.000    0.000 common.py:741(condition)
#         1    0.000    0.000    0.000    0.000 series.py:3146(_try_kind_sort)
#        37    0.000    0.000    0.000    0.000 managers.py:1523(_block)
#         4    0.000    0.000    0.000    0.000 common.py:1203(is_datetime64_ns_dtype)
#         4    0.000    0.000    0.000    0.000 {built-in method pandas._libs.lib.is_datetime_array}
#        10    0.000    0.000    0.000    0.000 {built-in method numpy.seterrobj}
#         2    0.000    0.000    0.000    0.000 series.py:720(__len__)
#        12    0.000    0.000    0.000    0.000 base.py:700(_reset_identity)
#         3    0.000    0.000    0.000    0.000 common.py:862(is_dtype_equal)
#         4    0.000    0.000    0.000    0.000 common.py:1253(is_timedelta64_ns_dtype)
#         9    0.000    0.000    0.000    0.000 {pandas._libs.lib.values_from_object}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#         1    0.000    0.000    0.000    0.000 inference.py:246(is_array_like)
#         5    0.000    0.000    0.000    0.000 _ufunc_config.py:437(__init__)
#         1    0.000    0.000    0.000    0.000 {method 'argsort' of 'numpy.ndarray' objects}
#        29    0.000    0.000    0.000    0.000 blocks.py:343(dtype)
#         3    0.000    0.000    0.000    0.000 numpy_.py:165(__array__)
#         4    0.000    0.000    0.000    0.000 nanops.py:65(<genexpr>)
#        19    0.000    0.000    0.000    0.000 common.py:214(classes_and_not_datetimelike)
#         1    0.000    0.000    0.000    0.000 {method 'all' of 'numpy.ndarray' objects}
#         7    0.000    0.000    0.000    0.000 base.py:617(<dictcomp>)
#         4    0.000    0.000    0.000    0.000 cast.py:1264(construct_1d_ndarray_preserving_na)
#         1    0.000    0.000    0.000    0.000 __init__.py:81(get_op_result_name)
#         2    0.000    0.000    0.000    0.000 {pandas._libs.lib.infer_datetimelike_array}
#         1    0.000    0.000    0.000    0.000 re.py:231(compile)
#         3    0.000    0.000    0.000    0.000 {method 'match' of '_sre.SRE_Pattern' objects}
#         1    0.000    0.000    0.000    0.000 _methods.py:47(_all)
#         6    0.000    0.000    0.000    0.000 series.py:443(_set_subtyp)
#         2    0.000    0.000    0.000    0.000 managers.py:325(__len__)
#         6    0.000    0.000    0.000    0.000 blocks.py:131(_check_ndim)
#         3    0.000    0.000    0.000    0.000 _internal.py:865(npy_ctypes_check)
#         1    0.000    0.000    0.000    0.000 re.py:286(_compile)
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.arange}
#         9    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#         7    0.000    0.000    0.000    0.000 series.py:460(name)
#         2    0.000    0.000    0.000    0.000 sparse.py:223(construct_from_string)
#         3    0.000    0.000    0.000    0.000 nanops.py:58(check)
#         2    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#         6    0.000    0.000    0.000    0.000 {method 'view' of 'numpy.ndarray' objects}
#         4    0.000    0.000    0.000    0.000 common.py:180(ensure_python_int)
#        20    0.000    0.000    0.000    0.000 {built-in method numpy.geterrobj}
#         1    0.000    0.000    0.000    0.000 __init__.py:1298(info)
#         2    0.000    0.000    0.000    0.000 inference.py:386(is_hashable)
#         2    0.000    0.000    0.000    0.000 inference.py:120(is_iterator)
#         1    0.000    0.000    0.000    0.000 common.py:1553(is_string_like_dtype)
#         2    0.000    0.000    0.000    0.000 {method 'search' of '_sre.SRE_Pattern' objects}
#         3    0.000    0.000    0.000    0.000 nanops.py:340(_na_ok_dtype)
#         8    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#         8    0.000    0.000    0.000    0.000 blocks.py:207(internal_values)
#         3    0.000    0.000    0.000    0.000 base.py:4118(_coerce_to_ndarray)
#         2    0.000    0.000    0.000    0.000 nanops.py:173(_get_fill_value)
#         2    0.000    0.000    0.000    0.000 range.py:652(__len__)
#         1    0.000    0.000    0.000    0.000 _validators.py:231(validate_bool_kwarg)
#         1    0.000    0.000    0.000    0.000 common.py:150(cast_scalar_indexer)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#         1    0.000    0.000    0.000    0.000 boundary_types.py:49(<listcomp>)
#         2    0.000    0.000    0.000    0.000 series.py:399(_constructor)
#         6    0.000    0.000    0.000    0.000 blocks.py:239(mgr_locs)
#         2    0.000    0.000    0.000    0.000 managers.py:236(items)
#         2    0.000    0.000    0.000    0.000 base.py:526(<genexpr>)
#         2    0.000    0.000    0.000    0.000 common.py:185(_all_none)
#         2    0.000    0.000    0.000    0.000 function.py:42(__call__)
#         4    0.000    0.000    0.000    0.000 common.py:1281(<lambda>)
#         1    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:74(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 sre_compile.py:539(isstring)
#         2    0.000    0.000    0.000    0.000 {method 'setdefault' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 range.py:236(start)
#         7    0.000    0.000    0.000    0.000 {pandas._libs.algos.ensure_object}
#         1    0.000    0.000    0.000    0.000 common.py:1582(<lambda>)
#         2    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_bool}
#         1    0.000    0.000    0.000    0.000 {method 'copy' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         1    0.000    0.000    0.000    0.000 range.py:259(stop)
#         1    0.000    0.000    0.000    0.000 base.py:747(dtype)
#         1    0.000    0.000    0.000    0.000 {built-in method pandas._libs.missing.checknull}
#         1    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 numeric.py:2295(_array_equal_dispatcher)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         2    0.000    0.000    0.000    0.000 range.py:170(_validate_dtype)
#         1    0.000    0.000    0.000    0.000 range.py:282(step)
#         1    0.000    0.000    0.000    0.000 numeric.py:134(is_all_dates)
#         5    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_integer}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_float}
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:2787(_prod_dispatcher)

# %% [markdown]
# I can see that both the `context` manager (0.380) and the `add_boundary` method (0.291) put a bigger overhead to the performance than the set_linear_coefficient  calls in the new test (0.125, with 2x more calls).
#
# I don't see anything unexpected but I don't know if this value of 0.125 should be lower or it scales poorly with bigger models (which it shouldn't).
